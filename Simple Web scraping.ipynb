# %%
import requests
import bs4
import pandas as pd

# %%
res=requests.get('https://www.imdb.com/list/ls000049962/')
soup=bs4.BeautifulSoup(res.text,'lxml')

# %%
p=soup.select('h3.lister-item-header')

# %%
y=[]
for i in p:
    y.append(i.text)

# %%
a=z.split('\n')

# %%
def select(x):
    i=2
    b=[]
    while i < 401:
        c=a[i]
        b.append(c)
        i=i+4
    return b

# %%
g=select(a)

# %%
g
# Out:
# ['The Shawshank Redemption',
#  'The Godfather',
#  'The Godfather: Part II',
#  'Il buono, il brutto, il cattivo',
#  'Pulp Fiction',
#  "Schindler's List",
#  '12 Angry Men',
#  'Inception',
#  "One Flew Over the Cuckoo's Nest",
#  'The Dark Knight',
#  'Star Wars: Episode V - The Empire Strikes Back',
#  'The Lord of the Rings: The Return of the King',
#  'Shichinin no samurai',
#  'Fight Club',
#  'Goodfellas',
#  'Star Wars',
#  'Casablanca',
#  'Cidade de Deus',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'Once Upon a Time in the West',
#  'Rear Window',
#  'Raiders of the Lost Ark',
#  'Psycho',
#  'The Usual Suspects',
#  'The Silence of the Lambs',
#  'Se7en',
#  "It's a Wonderful Life",
#  'Memento',
#  'Toy Story 3',
#  'The Lord of the Rings: The Two Towers',
#  'Sunset Blvd.',
#  'Forrest Gump',
#  'Léon',
#  'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#  'Apocalypse Now',
#  'Citizen Kane',
#  'North by Northwest',
# ...

# %%
f=pd.DataFrame(g,list(range(1,101)),['name of the movie'])

# %%
f
# Out:
#                    name of the movie
# 1           The Shawshank Redemption
# 2                      The Godfather
# 3             The Godfather: Part II
# 4    Il buono, il brutto, il cattivo
# 5                       Pulp Fiction
# ..                               ...
# 96                         Gladiator
# 97                       Gran Torino
# 98                         The Sting
# 99                        Unforgiven
# 100                         Oldeuboi
#
# [100 rows x 1 columns]

# %%
ratings_requester=requests.get('https://www.imdb.com/list/ls000049962/')
soupy=bs4.BeautifulSoup(ratings_requester.text,'lxml')
h=soupy.select('span.ipl-rating-star__rating')

# %%
j=[]
for i in h:
    j.append(i.text)

# %%
k=[]
i=0
while i<2300:
    
    c=j[i]
    k.append(c)
    i=i+23

# %%
k
# Out:
# ['9.3',
#  '9.2',
#  '9',
#  '8.8',
#  '8.9',
#  '8.9',
#  '8.9',
#  '8.8',
#  '8.7',
#  '9',
#  '8.7',
#  '8.9',
#  '8.6',
#  '8.8',
#  '8.7',
#  '8.6',
#  '8.5',
#  '8.6',
#  '8.8',
#  '8.5',
#  '8.5',
#  '8.4',
#  '8.5',
#  '8.5',
#  '8.6',
#  '8.6',
#  '8.6',
#  '8.4',
#  '8.3',
#  '8.7',
#  '8.4',
#  '8.8',
#  '8.5',
#  '8.4',
#  '8.4',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.5',
#  '8.3',
#  '8.5',
#  '8.6',
#  '8.3',
#  '8.4',
#  '8.3',
#  '8.4',
#  '8.6',
#  '8.4',
#  '8.4',
#  '8.3',
#  '8.5',
#  '8.3',
#  '8.3',
#  '8.5',
#  '8.4',
#  '8.3',
#  '8.5',
#  '8.3',
#  '8.4',
#  '8',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.1',
#  '8.3',
#  '8.2',
#  '8.5',
#  '8.2',
#  '8.6',
#  '8.2',
#  '8.5',
#  '8.5',
#  '8.2',
#  '8.2',
#  '8.2',
#  '8.5',
#  '8.3',
#  '8.2',
#  '8.1',
#  '8.2',
#  '8.4',
#  '8.6',
#  '8.3',
#  '8.2',
#  '8.3',
#  '8.3',
#  '8.5',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.3',
#  '8.2',
#  '8.2',
#  '8',
#  '8.3',
#  '8.5',
#  '8.1',
#  '8.3',
#  '8.2',
#  '8.4']

# %%
f=pd.DataFrame(g,list(range(1,101)),['name of the movie'])

# %%
f['IMDb ratings']=k

# %%
pd.set_option('display.max_rows',200)

# %%
f
# Out:
#                                      name of the movie IMDb ratings
# 1                             The Shawshank Redemption          9.3
# 2                                        The Godfather          9.2
# 3                               The Godfather: Part II            9
# 4                      Il buono, il brutto, il cattivo          8.8
# 5                                         Pulp Fiction          8.9
# 6                                     Schindler's List          8.9
# 7                                         12 Angry Men          8.9
# 8                                            Inception          8.8
# 9                      One Flew Over the Cuckoo's Nest          8.7
# 10                                     The Dark Knight            9
# 11      Star Wars: Episode V - The Empire Strikes Back          8.7
# 12       The Lord of the Rings: The Return of the King          8.9
# 13                                Shichinin no samurai          8.6
# ...
